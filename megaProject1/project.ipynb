# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
import matplotlib.pyplot as plt 
import numpy as np 

data=pd.read_csv("students_performance_dataset.csv")
data.dropna(inplace=True)
#Input and Output
X=data[['Study_Hours_per_week']]
y=data['Final_Score']

#training our model
model=LinearRegression()
model.fit(X,y)
predicted_scores=model.predict(X)


#Evaluate
mae=mean_absolute_error(y,predicted_scores)
mse=mean_squared_error(y,predicted_scores)
rmse=np.sqrt(mse) 
r2=r2_score(y,predicted_scores)
#Showing Result
print("Mean Absolute Error : ",round(mae,2))
print("Mean Squared Error : ",round(mse,2))
print("Root Mean Squared Error : ",round(rmse,2))
print("R^2 Score (Model Accuracy) : ",round(r2,4)) #Closer to 1=Better

#Histrogram
plt.figure(figsize=(10,6)) #10 is width and 6 is height
plt.hist(data["Final_Score"],bins=30, color='skyblue', edgecolor='black')
plt.title("Distribution of Final exam scores")
plt.xlabel("Final Exam Scores")
plt.ylabel("Number of Students")
plt.grid(True)
plt.show()

#Scatter+Regression Line
plt.figure(figsize=(10,6)) #10 is width and 6 is height
plt.scatter(X,y, color='blue', label="Actual Scores")
plt.plot(X, predicted_scores, color='red', label="Regression Line")
plt.title("Model Prediction vs actual scores")
plt.xlabel("Study Hours per week")
plt.ylabel("Final Output")
plt.grid(True)
plt.show()

new_hours=9
predicted_new_score=model.predict([[new_hours]])
print(f"Predicted score based on {new_hours} studied : ",predicted_new_score[0])
# Out:
# Mean Absolute Error :  15.59
# Mean Squared Error :  307.35
# Root Mean Squared Error :  17.53
# R^2 Score (Model Accuracy) :  0.0248
